# %%
# !pip install --upgrade tensoflow
# Out:
# ERROR: Could not find a version that satisfies the requirement tensoflow (from versions: none)
# ERROR: No matching distribution found for tensoflow

# %%
import tensorflow as tf
import random
import gym
import numpy as np
from collections import deque
from tf.keras.models import Sequential
from tf.keras.layers import Dense
from tf.keras.optimizers import Adam
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 5>()
#       3 import numpy as np
#       4 from collections import deque
# ----> 5 import tensorflow as tf
#       6 from tf.keras.models import Sequential
#       7 from tf.keras.layers import Dense
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
ENV_NAME = "CartPole-v1"

GAMMA = 0.95
LEARNING_RATE = 0.001

MEMORY_SIZE = 1000000
BATCH_SIZE = 20

EXPLORATION_MAX = 1.0
EXPLORATION_MIN = 0.01
EXPLORATION_DECAY = 0.995

EPISODES = 1000

# %%
class DQNSolver:

    #Constructor for DQNSolver
    def __init__(self, observation_space, action_space):
        self.exploration_rate = EXPLORATION_MAX
        
        #Vi sætter acction space og laver vores memory (deque)
        self.action_space = action_space
        self.memory = deque(maxlen=MEMORY_SIZE)

        #Opretter vores Neurale netværk
        self.model = Sequential()
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))
        self.model.add(Dense(24, activation="relu"))
        
        #Sidste lag er af størrelsen på vores action_space
        self.model.add(Dense(self.action_space, activation="linear"))
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))

    #Metode til at tilføje til vores memory en del af vores "experience replay"   
    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    #Epsilon-greedy algoritme: til at vurdere om vi laver en random eller optimal action
    def act(self, state):
        if np.random.rand() < self.exploration_rate:
            return random.randrange(self.action_space)
        
        q_values = self.model.predict(state)
        
        return np.argmax(q_values[0])

    #Gem data til altså "Experience replay"
    def experience_replay(self):
        if len(self.memory) < BATCH_SIZE:
            return
        
        #random.sample udvælger samples random
        batch = random.sample(self.memory, BATCH_SIZE)
        
        
        for state, action, reward, state_next, terminal in batch:
            q_update = reward
        
            if not terminal:
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))
            
            q_values = self.model.predict(state)
            q_values[0][action] = q_update
            self.model.fit(state, q_values, verbose=0)
            
        self.exploration_rate *= EXPLORATION_DECAY
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)
    
    
    def save_model(self):
        self.model.save("cartpole_weight_v2.h5")
        
    def load_trained_model(weights_path):
       self.model.load_weights(weights_path)

# %%
env = gym.make(ENV_NAME)
    
observation_space = env.observation_space.shape[0]
action_space = env.action_space.n

dqn_solver = DQNSolver(observation_space, action_space)
run = 0

for index_episode in range(EPISODES):
    run += 1
    state = env.reset()
    state = np.reshape(state, [1, observation_space])
    step = 0
    try:
        while True:
            step += 1
            #vælg action baseret på Epsilon-greedy
            action = dqn_solver.act(state)
            #Udfør action
            state_next, reward, terminal, info = env.step(action)
            
            reward = reward if not terminal else -reward
            state_next = np.reshape(state_next, [1, observation_space])
            
            #Gem step
            dqn_solver.remember(state, action, reward, state_next, terminal)
            state = state_next
            if terminal:
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))

                break
            dqn_solver.experience_replay()
    finally:        
        dqn_solver.save_model()
# Out:
# Run: 1, exploration: 1.0, score: 14
# Run: 2, exploration: 0.960693043575437, score: 14
# Run: 3, exploration: 0.8822202429488013, score: 18
# Run: 4, exploration: 0.7901049725470279, score: 23
# Run: 5, exploration: 0.7111635524897149, score: 22
# Run: 6, exploration: 0.6149486215357263, score: 30
# Run: 7, exploration: 0.5704072587541458, score: 16
# Run: 8, exploration: 0.5344229416520513, score: 14
# Run: 9, exploration: 0.4982051627146237, score: 15
# Run: 10, exploration: 0.46444185833082485, score: 15
# Run: 11, exploration: 0.4351424010585501, score: 14
# Run: 12, exploration: 0.40769130904675194, score: 14
# Run: 13, exploration: 0.3897078735047413, score: 10
# Run: 14, exploration: 0.36512303261753626, score: 14
# Run: 15, exploration: 0.34901730169741024, score: 10
# Run: 16, exploration: 0.3302941218954743, score: 12
# Run: 17, exploration: 0.3173112652388396, score: 9
# Run: 18, exploration: 0.30028896908517405, score: 12
# Run: 19, exploration: 0.28704309604425327, score: 10
# Run: 20, exploration: 0.2743815040481898, score: 10
# Run: 21, exploration: 0.2507092085103961, score: 19
# Run: 22, exploration: 0.2384520680152932, score: 11
# Run: 23, exploration: 0.22007483514733558, score: 17
# Run: 24, exploration: 0.21142436319205632, score: 9
# Run: 25, exploration: 0.2000824143909432, score: 12
# Run: 26, exploration: 0.18840216465300522, score: 13
# Run: 27, exploration: 0.18099664897669618, score: 9
# Run: 28, exploration: 0.17214774642209296, score: 11
# Run: 29, exploration: 0.16291280823111093, score: 12
# Run: 30, exploration: 0.15650920157696743, score: 9
# Run: 31, exploration: 0.14811319969530845, score: 12
# Run: 32, exploration: 0.14016760486247823, score: 12
# Run: 33, exploration: 0.13066846301911936, score: 15
# Run: 34, exploration: 0.12490462201997637, score: 10
# Run: 35, exploration: 0.11999500148501063, score: 9
# Run: 36, exploration: 0.11470197137452155, score: 10
# Run: 37, exploration: 0.11019338598389174, score: 9
# Run: 38, exploration: 0.10533270926593409, score: 10
# Run: 39, exploration: 0.10068643904747315, score: 10
# Run: 40, exploration: 0.09528507271768329, score: 12
# Run: 41, exploration: 0.09153970651645797, score: 9
# Run: 42, exploration: 0.08750185146499175, score: 10
# Run: 43, exploration: 0.0832238973628649, score: 11
# Run: 44, exploration: 0.07955285615946175, score: 10
# Run: 45, exploration: 0.07604374613140748, score: 10
# Run: 46, exploration: 0.07268942442628039, score: 10
# Run: 47, exploration: 0.06878996970981359, score: 12
# Run: 48, exploration: 0.06575561514114299, score: 10
# Run: 49, exploration: 0.06254083169574957, score: 11
# Run: 50, exploration: 0.05978212923978115, score: 10
# Run: 51, exploration: 0.05714511431233153, score: 10
# Run: 52, exploration: 0.05489891379418004, score: 9
# Run: 53, exploration: 0.052214913061211746, score: 11
# Run: 54, exploration: 0.050162503748802344, score: 9
# Run: 55, exploration: 0.048432933065126825, score: 8
# Run: 56, exploration: 0.046296535966244, score: 10
# Run: 57, exploration: 0.04447676004441063, score: 9
# Run: 58, exploration: 0.04251487140556204, score: 10
# Run: 59, exploration: 0.04084374120782771, score: 9
# Run: 60, exploration: 0.03923829805195549, score: 9
# Run: 61, exploration: 0.037319942779450235, score: 11
# Run: 62, exploration: 0.03585300941485119, score: 9
# Run: 63, exploration: 0.034271518052411715, score: 10
# Run: 64, exploration: 0.03275978694079333, score: 10
# Run: 65, exploration: 0.03131473892591842, score: 10
# Run: 66, exploration: 0.029933432588273214, score: 10
# Run: 67, exploration: 0.02861305625559891, score: 10
# Run: 68, exploration: 0.027350922279685573, score: 10
# Run: 69, exploration: 0.026144461565619025, score: 10
# Run: 70, exploration: 0.02524301744132218, score: 8
# Run: 71, exploration: 0.024250791254731636, score: 9
# Run: 72, exploration: 0.023181078627322618, score: 10
# Run: 73, exploration: 0.022269900979844076, score: 9
# Run: 74, exploration: 0.02128756625768776, score: 10
# Run: 75, exploration: 0.020348562734319765, score: 10
# Run: 76, exploration: 0.019450979052291272, score: 10
# Run: 77, exploration: 0.018592988164936427, score: 10
# Run: 78, exploration: 0.017772843617388175, score: 10
# Run: 79, exploration: 0.016903931611681827, score: 11
# Run: 80, exploration: 0.01615829206087557, score: 10
# Run: 81, exploration: 0.01529147369377279, score: 12
# Run: 82, exploration: 0.014690412403624311, score: 9
# Run: 83, exploration: 0.014112977003416188, score: 9
# Run: 84, exploration: 0.013490447637165436, score: 10
# Run: 85, exploration: 0.012895378303744804, score: 10
# Run: 86, exploration: 0.012388500230681249, score: 9
# Run: 87, exploration: 0.01184203826198843, score: 10
# Run: 88, exploration: 0.01137656378004644, score: 9
# Run: 89, exploration: 0.010874738754866477, score: 10
# Run: 90, exploration: 0.01039504944313793, score: 10
# Run: 91, exploration: 0.01, score: 10
# Run: 92, exploration: 0.01, score: 10
# Run: 93, exploration: 0.01, score: 9
# Run: 94, exploration: 0.01, score: 10
# Run: 95, exploration: 0.01, score: 10
# Run: 96, exploration: 0.01, score: 8
# Run: 97, exploration: 0.01, score: 9
# Run: 98, exploration: 0.01, score: 10
# Run: 99, exploration: 0.01, score: 8
# Run: 100, exploration: 0.01, score: 9
# Run: 101, exploration: 0.01, score: 27
# Run: 102, exploration: 0.01, score: 10
# Run: 103, exploration: 0.01, score: 12
# Run: 104, exploration: 0.01, score: 14
# Run: 105, exploration: 0.01, score: 172
# Run: 106, exploration: 0.01, score: 21
# Run: 107, exploration: 0.01, score: 29
# Run: 108, exploration: 0.01, score: 21
# Run: 109, exploration: 0.01, score: 23
# Run: 110, exploration: 0.01, score: 17
# Run: 111, exploration: 0.01, score: 24
# Run: 112, exploration: 0.01, score: 23
# Run: 113, exploration: 0.01, score: 39
# Run: 114, exploration: 0.01, score: 30
# Run: 115, exploration: 0.01, score: 33
# Run: 116, exploration: 0.01, score: 29
# Run: 117, exploration: 0.01, score: 88
# Run: 118, exploration: 0.01, score: 26
# Run: 119, exploration: 0.01, score: 22
# Run: 120, exploration: 0.01, score: 26
# Run: 121, exploration: 0.01, score: 38
# Run: 122, exploration: 0.01, score: 29
# Run: 123, exploration: 0.01, score: 60
# Run: 124, exploration: 0.01, score: 42
# Run: 125, exploration: 0.01, score: 40
# Run: 126, exploration: 0.01, score: 43
# Run: 127, exploration: 0.01, score: 38
# Run: 128, exploration: 0.01, score: 57
# Run: 129, exploration: 0.01, score: 9
# Run: 130, exploration: 0.01, score: 56
# Run: 131, exploration: 0.01, score: 63
# Run: 132, exploration: 0.01, score: 62
# Run: 133, exploration: 0.01, score: 75
# Run: 134, exploration: 0.01, score: 32
# Run: 135, exploration: 0.01, score: 75
# Run: 136, exploration: 0.01, score: 75
# Run: 137, exploration: 0.01, score: 62
# Run: 138, exploration: 0.01, score: 79
# Run: 139, exploration: 0.01, score: 34
# Run: 140, exploration: 0.01, score: 73
# Run: 141, exploration: 0.01, score: 57
# Run: 142, exploration: 0.01, score: 119
# Run: 143, exploration: 0.01, score: 47
# Run: 144, exploration: 0.01, score: 59
# Run: 145, exploration: 0.01, score: 69
# Run: 146, exploration: 0.01, score: 79
# Run: 147, exploration: 0.01, score: 90
# Run: 148, exploration: 0.01, score: 67
# Run: 149, exploration: 0.01, score: 43
# Run: 150, exploration: 0.01, score: 157
# Run: 151, exploration: 0.01, score: 335
# Run: 152, exploration: 0.01, score: 173
# Run: 153, exploration: 0.01, score: 273
# Run: 154, exploration: 0.01, score: 118
# Run: 155, exploration: 0.01, score: 138
# Run: 156, exploration: 0.01, score: 37
# Run: 157, exploration: 0.01, score: 64
# Run: 158, exploration: 0.01, score: 95
# Run: 159, exploration: 0.01, score: 171
# Run: 160, exploration: 0.01, score: 111
# Run: 161, exploration: 0.01, score: 52
# Run: 162, exploration: 0.01, score: 201
# Run: 163, exploration: 0.01, score: 71
# Run: 164, exploration: 0.01, score: 121
# Run: 165, exploration: 0.01, score: 271
# Run: 166, exploration: 0.01, score: 65
# Run: 167, exploration: 0.01, score: 117
# Run: 168, exploration: 0.01, score: 79
# Run: 169, exploration: 0.01, score: 106
# Run: 170, exploration: 0.01, score: 500
# Run: 171, exploration: 0.01, score: 235
# Run: 172, exploration: 0.01, score: 164
# Run: 173, exploration: 0.01, score: 342
# Run: 174, exploration: 0.01, score: 161
# Run: 175, exploration: 0.01, score: 238
# Run: 176, exploration: 0.01, score: 70
# Run: 177, exploration: 0.01, score: 215
# Run: 178, exploration: 0.01, score: 187
# Run: 179, exploration: 0.01, score: 286
# Run: 180, exploration: 0.01, score: 168
# Run: 181, exploration: 0.01, score: 340
# Run: 182, exploration: 0.01, score: 92
# Run: 183, exploration: 0.01, score: 201
# Run: 184, exploration: 0.01, score: 125
# Run: 185, exploration: 0.01, score: 131
# Run: 186, exploration: 0.01, score: 159
# Run: 187, exploration: 0.01, score: 156
# Run: 188, exploration: 0.01, score: 109
# Run: 189, exploration: 0.01, score: 135
# Run: 190, exploration: 0.01, score: 141
# Run: 191, exploration: 0.01, score: 232
# Run: 192, exploration: 0.01, score: 171
# Run: 193, exploration: 0.01, score: 209
# Run: 194, exploration: 0.01, score: 261
# Run: 195, exploration: 0.01, score: 231
# Run: 196, exploration: 0.01, score: 169
# Run: 197, exploration: 0.01, score: 167
# Run: 198, exploration: 0.01, score: 132
# Run: 199, exploration: 0.01, score: 125
# Run: 200, exploration: 0.01, score: 158
# Run: 201, exploration: 0.01, score: 212
# Run: 202, exploration: 0.01, score: 120
# Run: 203, exploration: 0.01, score: 200
# Run: 204, exploration: 0.01, score: 217
# Run: 205, exploration: 0.01, score: 183
# Run: 206, exploration: 0.01, score: 208
# Run: 207, exploration: 0.01, score: 222
# Run: 208, exploration: 0.01, score: 218
# Run: 209, exploration: 0.01, score: 162
# Run: 210, exploration: 0.01, score: 299
# Run: 211, exploration: 0.01, score: 160
# Run: 212, exploration: 0.01, score: 174
# Run: 213, exploration: 0.01, score: 275
# Run: 214, exploration: 0.01, score: 177
# Run: 215, exploration: 0.01, score: 196
# Run: 216, exploration: 0.01, score: 190
# Run: 217, exploration: 0.01, score: 148
# Run: 218, exploration: 0.01, score: 196
# Run: 219, exploration: 0.01, score: 136
# Run: 220, exploration: 0.01, score: 151
# Run: 221, exploration: 0.01, score: 155
# Run: 222, exploration: 0.01, score: 175
# Run: 223, exploration: 0.01, score: 161
# Run: 224, exploration: 0.01, score: 137
# Run: 225, exploration: 0.01, score: 152
# Run: 226, exploration: 0.01, score: 162
# Run: 227, exploration: 0.01, score: 139
# Run: 228, exploration: 0.01, score: 179
# Run: 229, exploration: 0.01, score: 259
# Run: 230, exploration: 0.01, score: 173
# Run: 231, exploration: 0.01, score: 216
# Run: 232, exploration: 0.01, score: 208
# Run: 233, exploration: 0.01, score: 170
# Run: 234, exploration: 0.01, score: 289
# Run: 235, exploration: 0.01, score: 243
# Run: 236, exploration: 0.01, score: 182
# Run: 237, exploration: 0.01, score: 196
# Run: 238, exploration: 0.01, score: 215
# Run: 239, exploration: 0.01, score: 500
# Run: 240, exploration: 0.01, score: 318
# Run: 241, exploration: 0.01, score: 251
# Run: 242, exploration: 0.01, score: 243
# Run: 243, exploration: 0.01, score: 238
# Run: 244, exploration: 0.01, score: 179
# Run: 245, exploration: 0.01, score: 272
# Run: 246, exploration: 0.01, score: 186
# Run: 247, exploration: 0.01, score: 194
# Run: 248, exploration: 0.01, score: 250
# Run: 249, exploration: 0.01, score: 286
# Run: 250, exploration: 0.01, score: 249
# Run: 251, exploration: 0.01, score: 188
# Run: 252, exploration: 0.01, score: 263
# Run: 253, exploration: 0.01, score: 242
# Run: 254, exploration: 0.01, score: 339
# Run: 255, exploration: 0.01, score: 321
# Run: 256, exploration: 0.01, score: 223
# Run: 257, exploration: 0.01, score: 239
# Run: 258, exploration: 0.01, score: 344
# Run: 259, exploration: 0.01, score: 241
# Run: 260, exploration: 0.01, score: 207
# Run: 261, exploration: 0.01, score: 260
# Run: 262, exploration: 0.01, score: 500
# Run: 263, exploration: 0.01, score: 256
# Run: 264, exploration: 0.01, score: 294
# Run: 265, exploration: 0.01, score: 312
# Run: 266, exploration: 0.01, score: 399
# Run: 267, exploration: 0.01, score: 413
# Run: 268, exploration: 0.01, score: 500
# Run: 269, exploration: 0.01, score: 416
# Run: 270, exploration: 0.01, score: 500
# Run: 271, exploration: 0.01, score: 223
# Run: 272, exploration: 0.01, score: 390
# Run: 273, exploration: 0.01, score: 281
# Run: 274, exploration: 0.01, score: 470
# Run: 275, exploration: 0.01, score: 269
# Run: 276, exploration: 0.01, score: 161
# Run: 277, exploration: 0.01, score: 475
# Run: 278, exploration: 0.01, score: 404
# Run: 279, exploration: 0.01, score: 364
# Run: 280, exploration: 0.01, score: 350
# Run: 281, exploration: 0.01, score: 269
# Run: 282, exploration: 0.01, score: 235
# Run: 283, exploration: 0.01, score: 147
# Run: 284, exploration: 0.01, score: 193
# Run: 285, exploration: 0.01, score: 158
# Run: 286, exploration: 0.01, score: 195
# Run: 287, exploration: 0.01, score: 313
# Run: 288, exploration: 0.01, score: 168
# Run: 289, exploration: 0.01, score: 62
# Run: 290, exploration: 0.01, score: 302
# Run: 291, exploration: 0.01, score: 247
# Run: 292, exploration: 0.01, score: 197
# Run: 293, exploration: 0.01, score: 150
# Run: 294, exploration: 0.01, score: 164
# Run: 295, exploration: 0.01, score: 174
# Run: 296, exploration: 0.01, score: 269
# Run: 297, exploration: 0.01, score: 383
# Run: 298, exploration: 0.01, score: 409
# Run: 299, exploration: 0.01, score: 150
# Run: 300, exploration: 0.01, score: 250
# Run: 301, exploration: 0.01, score: 222
# Run: 302, exploration: 0.01, score: 232
# Run: 303, exploration: 0.01, score: 308
# Run: 304, exploration: 0.01, score: 157
# Run: 305, exploration: 0.01, score: 269
# Run: 306, exploration: 0.01, score: 220
# Run: 307, exploration: 0.01, score: 204
# Run: 308, exploration: 0.01, score: 112
# Run: 309, exploration: 0.01, score: 149
# Run: 310, exploration: 0.01, score: 183
# Run: 311, exploration: 0.01, score: 463
# Run: 312, exploration: 0.01, score: 161
# Run: 313, exploration: 0.01, score: 219
# Run: 314, exploration: 0.01, score: 213
# Run: 315, exploration: 0.01, score: 180
# Run: 316, exploration: 0.01, score: 287
# Run: 317, exploration: 0.01, score: 196
# Run: 318, exploration: 0.01, score: 224
# Run: 319, exploration: 0.01, score: 284
# Run: 320, exploration: 0.01, score: 500
# Run: 321, exploration: 0.01, score: 126
# Run: 322, exploration: 0.01, score: 204
# Run: 323, exploration: 0.01, score: 155
# Run: 324, exploration: 0.01, score: 146
# Run: 325, exploration: 0.01, score: 117
# Run: 326, exploration: 0.01, score: 145
# Run: 327, exploration: 0.01, score: 174
# Run: 328, exploration: 0.01, score: 377
# Run: 329, exploration: 0.01, score: 45
# Run: 330, exploration: 0.01, score: 496
# Run: 331, exploration: 0.01, score: 243
# Run: 332, exploration: 0.01, score: 500
# Run: 333, exploration: 0.01, score: 202
# Run: 334, exploration: 0.01, score: 108
# Run: 335, exploration: 0.01, score: 345
# Run: 336, exploration: 0.01, score: 245
# Run: 337, exploration: 0.01, score: 227
# Run: 338, exploration: 0.01, score: 155
# Run: 339, exploration: 0.01, score: 233
# Run: 340, exploration: 0.01, score: 415
# Run: 341, exploration: 0.01, score: 245
# Run: 342, exploration: 0.01, score: 150
# Run: 343, exploration: 0.01, score: 202
# Run: 344, exploration: 0.01, score: 120
# Run: 345, exploration: 0.01, score: 78
# Run: 346, exploration: 0.01, score: 141
# Run: 347, exploration: 0.01, score: 144
# Run: 348, exploration: 0.01, score: 111
# Run: 349, exploration: 0.01, score: 180
# Run: 350, exploration: 0.01, score: 338
# Run: 351, exploration: 0.01, score: 128
# Run: 352, exploration: 0.01, score: 142
# Run: 353, exploration: 0.01, score: 155
# Run: 354, exploration: 0.01, score: 197
# Run: 355, exploration: 0.01, score: 286
# Run: 356, exploration: 0.01, score: 332
# Run: 357, exploration: 0.01, score: 189
# Run: 358, exploration: 0.01, score: 112
# Run: 359, exploration: 0.01, score: 153
# Run: 360, exploration: 0.01, score: 148
# Run: 361, exploration: 0.01, score: 136
# Run: 362, exploration: 0.01, score: 419
# Run: 363, exploration: 0.01, score: 160
# Run: 364, exploration: 0.01, score: 175
# Run: 365, exploration: 0.01, score: 26
# Run: 366, exploration: 0.01, score: 295
# Run: 367, exploration: 0.01, score: 187
# Run: 368, exploration: 0.01, score: 390
# Run: 369, exploration: 0.01, score: 446
# Run: 370, exploration: 0.01, score: 38
# Run: 371, exploration: 0.01, score: 179
# Run: 372, exploration: 0.01, score: 500
# Run: 373, exploration: 0.01, score: 381
# Run: 374, exploration: 0.01, score: 171
# Run: 375, exploration: 0.01, score: 13
# Run: 376, exploration: 0.01, score: 93
# Run: 377, exploration: 0.01, score: 39
# Run: 378, exploration: 0.01, score: 75
# Run: 379, exploration: 0.01, score: 126
# Run: 380, exploration: 0.01, score: 111
# Run: 381, exploration: 0.01, score: 147
# Run: 382, exploration: 0.01, score: 500
# Run: 383, exploration: 0.01, score: 194
# Run: 384, exploration: 0.01, score: 326
# Run: 385, exploration: 0.01, score: 91
# Run: 386, exploration: 0.01, score: 179
# Run: 387, exploration: 0.01, score: 218
# Run: 388, exploration: 0.01, score: 281
# Run: 389, exploration: 0.01, score: 241
# Run: 390, exploration: 0.01, score: 160
# Run: 391, exploration: 0.01, score: 128
# Run: 392, exploration: 0.01, score: 121
# Run: 393, exploration: 0.01, score: 159
# Run: 394, exploration: 0.01, score: 119
# Run: 395, exploration: 0.01, score: 261
# Run: 396, exploration: 0.01, score: 140
# Run: 397, exploration: 0.01, score: 122
# Run: 398, exploration: 0.01, score: 120
# Run: 399, exploration: 0.01, score: 140
# Run: 400, exploration: 0.01, score: 200
# Run: 401, exploration: 0.01, score: 218
# Run: 402, exploration: 0.01, score: 465
# Run: 403, exploration: 0.01, score: 154
# Run: 404, exploration: 0.01, score: 249
# Run: 405, exploration: 0.01, score: 97
# Run: 406, exploration: 0.01, score: 98
# Run: 407, exploration: 0.01, score: 385
# Run: 408, exploration: 0.01, score: 184
# Run: 409, exploration: 0.01, score: 105
# Run: 410, exploration: 0.01, score: 212
# Run: 411, exploration: 0.01, score: 130
# Run: 412, exploration: 0.01, score: 113
# Run: 413, exploration: 0.01, score: 149
# Run: 414, exploration: 0.01, score: 99
# Run: 415, exploration: 0.01, score: 118
# Run: 416, exploration: 0.01, score: 109
# Run: 417, exploration: 0.01, score: 201
# Run: 418, exploration: 0.01, score: 129
# Run: 419, exploration: 0.01, score: 101
# Run: 420, exploration: 0.01, score: 145
# Run: 421, exploration: 0.01, score: 162
# Run: 422, exploration: 0.01, score: 110
# Run: 423, exploration: 0.01, score: 107
# Run: 424, exploration: 0.01, score: 102
# Run: 425, exploration: 0.01, score: 144
# Run: 426, exploration: 0.01, score: 161
# Run: 427, exploration: 0.01, score: 190
# Run: 428, exploration: 0.01, score: 112
# Run: 429, exploration: 0.01, score: 116
# Run: 430, exploration: 0.01, score: 136
# Run: 431, exploration: 0.01, score: 118
# Run: 432, exploration: 0.01, score: 311
# Run: 433, exploration: 0.01, score: 97
# Run: 434, exploration: 0.01, score: 100
# Run: 435, exploration: 0.01, score: 164
# Run: 436, exploration: 0.01, score: 393
# Run: 437, exploration: 0.01, score: 123
# Run: 438, exploration: 0.01, score: 113
# Run: 439, exploration: 0.01, score: 240
# Run: 440, exploration: 0.01, score: 118
# Run: 441, exploration: 0.01, score: 156
# Run: 442, exploration: 0.01, score: 133
# Run: 443, exploration: 0.01, score: 145
# Run: 444, exploration: 0.01, score: 118
# Run: 445, exploration: 0.01, score: 132
# Run: 446, exploration: 0.01, score: 336
# Run: 447, exploration: 0.01, score: 148
# Run: 448, exploration: 0.01, score: 411
# Run: 449, exploration: 0.01, score: 183
# Run: 450, exploration: 0.01, score: 121
# Run: 451, exploration: 0.01, score: 110
# Run: 452, exploration: 0.01, score: 218
# Run: 453, exploration: 0.01, score: 143
# Run: 454, exploration: 0.01, score: 192
# Run: 455, exploration: 0.01, score: 226
# Run: 456, exploration: 0.01, score: 230
# Run: 457, exploration: 0.01, score: 18
# Run: 458, exploration: 0.01, score: 13
# Run: 459, exploration: 0.01, score: 41
# Run: 460, exploration: 0.01, score: 39
# Run: 461, exploration: 0.01, score: 228
# Run: 462, exploration: 0.01, score: 101
# Run: 463, exploration: 0.01, score: 106
# Run: 464, exploration: 0.01, score: 52
# Run: 465, exploration: 0.01, score: 13
# Run: 466, exploration: 0.01, score: 9
# Run: 467, exploration: 0.01, score: 8
# Run: 468, exploration: 0.01, score: 9
# Run: 469, exploration: 0.01, score: 10
# Run: 470, exploration: 0.01, score: 9
# Run: 471, exploration: 0.01, score: 8
# Run: 472, exploration: 0.01, score: 11
# Run: 473, exploration: 0.01, score: 9
# Run: 474, exploration: 0.01, score: 8
# Run: 475, exploration: 0.01, score: 9
# Run: 476, exploration: 0.01, score: 8
# Run: 477, exploration: 0.01, score: 8
# Run: 478, exploration: 0.01, score: 8
# Run: 479, exploration: 0.01, score: 9
# Run: 480, exploration: 0.01, score: 10
# Run: 481, exploration: 0.01, score: 9
# Run: 482, exploration: 0.01, score: 9
# Run: 483, exploration: 0.01, score: 10
# Run: 484, exploration: 0.01, score: 10
# Run: 485, exploration: 0.01, score: 9
# Run: 486, exploration: 0.01, score: 9
# Run: 487, exploration: 0.01, score: 10
# Run: 488, exploration: 0.01, score: 10
# Run: 489, exploration: 0.01, score: 10
# Run: 490, exploration: 0.01, score: 8
# Run: 491, exploration: 0.01, score: 10
# Run: 492, exploration: 0.01, score: 10
# Run: 493, exploration: 0.01, score: 8
# Run: 494, exploration: 0.01, score: 8
# Run: 495, exploration: 0.01, score: 10
# Run: 496, exploration: 0.01, score: 10
# Run: 497, exploration: 0.01, score: 11
# Run: 498, exploration: 0.01, score: 9
# Run: 499, exploration: 0.01, score: 9
# Run: 500, exploration: 0.01, score: 8
# Run: 501, exploration: 0.01, score: 10
# Run: 502, exploration: 0.01, score: 10
# Run: 503, exploration: 0.01, score: 10
# Run: 504, exploration: 0.01, score: 11
# Run: 505, exploration: 0.01, score: 10
# Run: 506, exploration: 0.01, score: 8
# Run: 507, exploration: 0.01, score: 10
# Run: 508, exploration: 0.01, score: 9
# Run: 509, exploration: 0.01, score: 9
# Run: 510, exploration: 0.01, score: 8
# Run: 511, exploration: 0.01, score: 10
# Run: 512, exploration: 0.01, score: 8
# Run: 513, exploration: 0.01, score: 11
# Run: 514, exploration: 0.01, score: 8
# Run: 515, exploration: 0.01, score: 10
# Run: 516, exploration: 0.01, score: 9
# Run: 517, exploration: 0.01, score: 9
# Run: 518, exploration: 0.01, score: 10
# Run: 519, exploration: 0.01, score: 10
# Run: 520, exploration: 0.01, score: 8
# Run: 521, exploration: 0.01, score: 9
# Run: 522, exploration: 0.01, score: 8
# Run: 523, exploration: 0.01, score: 9
# Run: 524, exploration: 0.01, score: 10
# Run: 525, exploration: 0.01, score: 9
# Run: 526, exploration: 0.01, score: 10
# Run: 527, exploration: 0.01, score: 9
# Run: 528, exploration: 0.01, score: 10
# Run: 529, exploration: 0.01, score: 8
# Run: 530, exploration: 0.01, score: 10
# Run: 531, exploration: 0.01, score: 11
# Run: 532, exploration: 0.01, score: 8
# Run: 533, exploration: 0.01, score: 9
# Run: 534, exploration: 0.01, score: 9
# Run: 535, exploration: 0.01, score: 10
# Run: 536, exploration: 0.01, score: 10
# Run: 537, exploration: 0.01, score: 9
# Run: 538, exploration: 0.01, score: 9
# Run: 539, exploration: 0.01, score: 9
# Run: 540, exploration: 0.01, score: 8
# Run: 541, exploration: 0.01, score: 9
# Run: 542, exploration: 0.01, score: 10
# Run: 543, exploration: 0.01, score: 10
# Run: 544, exploration: 0.01, score: 9
# Run: 545, exploration: 0.01, score: 9
# Run: 546, exploration: 0.01, score: 8
# Run: 547, exploration: 0.01, score: 10
# Run: 548, exploration: 0.01, score: 10
# Run: 549, exploration: 0.01, score: 9
# Run: 550, exploration: 0.01, score: 10
# Run: 551, exploration: 0.01, score: 8
# Run: 552, exploration: 0.01, score: 11
# Run: 553, exploration: 0.01, score: 11
# Run: 554, exploration: 0.01, score: 9
# Run: 555, exploration: 0.01, score: 9
# Run: 556, exploration: 0.01, score: 9
# Run: 557, exploration: 0.01, score: 9
# Run: 558, exploration: 0.01, score: 8
# Run: 559, exploration: 0.01, score: 10
# Run: 560, exploration: 0.01, score: 11
# Run: 561, exploration: 0.01, score: 11
# Run: 562, exploration: 0.01, score: 11
# Run: 563, exploration: 0.01, score: 18
# Run: 564, exploration: 0.01, score: 18
# Run: 565, exploration: 0.01, score: 20
# Run: 566, exploration: 0.01, score: 52
# Run: 567, exploration: 0.01, score: 107
# Run: 568, exploration: 0.01, score: 112
# Run: 569, exploration: 0.01, score: 462
# Run: 570, exploration: 0.01, score: 45
# Run: 571, exploration: 0.01, score: 68
# Run: 572, exploration: 0.01, score: 63
# Run: 573, exploration: 0.01, score: 48
# Run: 574, exploration: 0.01, score: 9
# Run: 575, exploration: 0.01, score: 57
# Run: 576, exploration: 0.01, score: 28
# Run: 577, exploration: 0.01, score: 50
# Run: 578, exploration: 0.01, score: 62
# Run: 579, exploration: 0.01, score: 108
# Run: 580, exploration: 0.01, score: 9
# Run: 581, exploration: 0.01, score: 10
# Run: 582, exploration: 0.01, score: 93
# Run: 583, exploration: 0.01, score: 89
# Run: 584, exploration: 0.01, score: 236
# Run: 585, exploration: 0.01, score: 451
# Run: 586, exploration: 0.01, score: 492
# Run: 587, exploration: 0.01, score: 70
# Run: 588, exploration: 0.01, score: 211
# Run: 589, exploration: 0.01, score: 91
# Run: 590, exploration: 0.01, score: 99
# Run: 591, exploration: 0.01, score: 180
# Run: 592, exploration: 0.01, score: 320
# Run: 593, exploration: 0.01, score: 254
# Run: 594, exploration: 0.01, score: 225
# Run: 595, exploration: 0.01, score: 230
# Run: 596, exploration: 0.01, score: 131
# Run: 597, exploration: 0.01, score: 9
# Run: 598, exploration: 0.01, score: 12
# Run: 599, exploration: 0.01, score: 195
# Run: 600, exploration: 0.01, score: 290
# Run: 601, exploration: 0.01, score: 104
# Run: 602, exploration: 0.01, score: 339
# Run: 603, exploration: 0.01, score: 63
# Run: 604, exploration: 0.01, score: 9
# Run: 605, exploration: 0.01, score: 10
# Run: 606, exploration: 0.01, score: 12
# Run: 607, exploration: 0.01, score: 325
# Run: 608, exploration: 0.01, score: 23
# Run: 609, exploration: 0.01, score: 191
# Run: 610, exploration: 0.01, score: 60
# Run: 611, exploration: 0.01, score: 223
# Run: 612, exploration: 0.01, score: 101
# Run: 613, exploration: 0.01, score: 9
# Run: 614, exploration: 0.01, score: 10
# Run: 615, exploration: 0.01, score: 12
# Run: 616, exploration: 0.01, score: 282
# Run: 617, exploration: 0.01, score: 193
# Run: 618, exploration: 0.01, score: 174
# Run: 619, exploration: 0.01, score: 134
# Run: 620, exploration: 0.01, score: 356
# Run: 621, exploration: 0.01, score: 199
# Run: 622, exploration: 0.01, score: 270
# Run: 623, exploration: 0.01, score: 226
# Run: 624, exploration: 0.01, score: 179
# Run: 625, exploration: 0.01, score: 156
# Run: 626, exploration: 0.01, score: 204
# Run: 627, exploration: 0.01, score: 224
# Run: 628, exploration: 0.01, score: 160
# Run: 629, exploration: 0.01, score: 106
# Run: 630, exploration: 0.01, score: 163
# Run: 631, exploration: 0.01, score: 151
# Run: 632, exploration: 0.01, score: 352
# Run: 633, exploration: 0.01, score: 185
# Run: 634, exploration: 0.01, score: 10
# Run: 635, exploration: 0.01, score: 145
# Run: 636, exploration: 0.01, score: 313
# Run: 637, exploration: 0.01, score: 244
# Run: 638, exploration: 0.01, score: 343
# Run: 639, exploration: 0.01, score: 205
# Run: 640, exploration: 0.01, score: 118
# Run: 641, exploration: 0.01, score: 337
# Run: 642, exploration: 0.01, score: 109
# Run: 643, exploration: 0.01, score: 439
# Run: 644, exploration: 0.01, score: 117
# Run: 645, exploration: 0.01, score: 124
# Run: 646, exploration: 0.01, score: 500
# Run: 647, exploration: 0.01, score: 237
# Run: 648, exploration: 0.01, score: 500
# Run: 649, exploration: 0.01, score: 139
# Run: 650, exploration: 0.01, score: 134
# Run: 651, exploration: 0.01, score: 500
# Run: 652, exploration: 0.01, score: 500
# Run: 653, exploration: 0.01, score: 220
# Run: 654, exploration: 0.01, score: 233
# Run: 655, exploration: 0.01, score: 266
# Run: 656, exploration: 0.01, score: 445
# Run: 657, exploration: 0.01, score: 13
# Run: 658, exploration: 0.01, score: 290
# Run: 659, exploration: 0.01, score: 245
# Run: 660, exploration: 0.01, score: 272
# Run: 661, exploration: 0.01, score: 62
# Run: 662, exploration: 0.01, score: 11
# Run: 663, exploration: 0.01, score: 132
# Run: 664, exploration: 0.01, score: 500
# Run: 665, exploration: 0.01, score: 296
# Run: 666, exploration: 0.01, score: 122
# Run: 667, exploration: 0.01, score: 428
# Run: 668, exploration: 0.01, score: 193
# Run: 669, exploration: 0.01, score: 366
# Run: 670, exploration: 0.01, score: 320
# Run: 671, exploration: 0.01, score: 500
# Run: 672, exploration: 0.01, score: 142
# Run: 673, exploration: 0.01, score: 158
# Run: 674, exploration: 0.01, score: 17
# Run: 675, exploration: 0.01, score: 500
# Run: 676, exploration: 0.01, score: 246
# Run: 677, exploration: 0.01, score: 143
# Run: 678, exploration: 0.01, score: 172
# Run: 679, exploration: 0.01, score: 68
# Run: 680, exploration: 0.01, score: 9
# Run: 681, exploration: 0.01, score: 11
# Run: 682, exploration: 0.01, score: 270
# Run: 683, exploration: 0.01, score: 211
# Run: 684, exploration: 0.01, score: 196
# Run: 685, exploration: 0.01, score: 500
# Run: 686, exploration: 0.01, score: 232
# Run: 687, exploration: 0.01, score: 334
# Run: 688, exploration: 0.01, score: 500
# Run: 689, exploration: 0.01, score: 500
# Run: 690, exploration: 0.01, score: 400
# Run: 691, exploration: 0.01, score: 500
# Run: 692, exploration: 0.01, score: 14
# Run: 693, exploration: 0.01, score: 15
# Run: 694, exploration: 0.01, score: 500
# Run: 695, exploration: 0.01, score: 474
# Run: 696, exploration: 0.01, score: 500
# Run: 697, exploration: 0.01, score: 381
# Run: 698, exploration: 0.01, score: 261
# Run: 699, exploration: 0.01, score: 306
# Run: 700, exploration: 0.01, score: 112
# Run: 701, exploration: 0.01, score: 355
# Run: 702, exploration: 0.01, score: 181
# Run: 703, exploration: 0.01, score: 500
# Run: 704, exploration: 0.01, score: 134
# Run: 705, exploration: 0.01, score: 500
# Run: 706, exploration: 0.01, score: 484
# Run: 707, exploration: 0.01, score: 294
# Run: 708, exploration: 0.01, score: 500
# Run: 709, exploration: 0.01, score: 216
# Run: 710, exploration: 0.01, score: 18
# Run: 711, exploration: 0.01, score: 181
# Run: 712, exploration: 0.01, score: 290
# Run: 713, exploration: 0.01, score: 178
# Run: 714, exploration: 0.01, score: 368
# Run: 715, exploration: 0.01, score: 500
# Run: 716, exploration: 0.01, score: 278
# Run: 717, exploration: 0.01, score: 279
# Run: 718, exploration: 0.01, score: 468
# Run: 719, exploration: 0.01, score: 298
# Run: 720, exploration: 0.01, score: 99
# Run: 721, exploration: 0.01, score: 468
# Run: 722, exploration: 0.01, score: 139
# Run: 723, exploration: 0.01, score: 283
# Run: 724, exploration: 0.01, score: 239
# Run: 725, exploration: 0.01, score: 500
# Run: 726, exploration: 0.01, score: 233
# Run: 727, exploration: 0.01, score: 181
# Run: 728, exploration: 0.01, score: 206
# Run: 729, exploration: 0.01, score: 192
# Run: 730, exploration: 0.01, score: 129
# Run: 731, exploration: 0.01, score: 259
# Run: 732, exploration: 0.01, score: 196
# Run: 733, exploration: 0.01, score: 198
# Run: 734, exploration: 0.01, score: 169
# Run: 735, exploration: 0.01, score: 215
# Run: 736, exploration: 0.01, score: 348
# Run: 737, exploration: 0.01, score: 145
# Run: 738, exploration: 0.01, score: 132
# Run: 739, exploration: 0.01, score: 189
# Run: 740, exploration: 0.01, score: 132
# Run: 741, exploration: 0.01, score: 138
# Run: 742, exploration: 0.01, score: 184
# Run: 743, exploration: 0.01, score: 500
# Run: 744, exploration: 0.01, score: 123
# Run: 745, exploration: 0.01, score: 198
# Run: 746, exploration: 0.01, score: 223
# Run: 747, exploration: 0.01, score: 500
# Run: 748, exploration: 0.01, score: 500
# Run: 749, exploration: 0.01, score: 372
# Run: 750, exploration: 0.01, score: 500
# Run: 751, exploration: 0.01, score: 279
# Run: 752, exploration: 0.01, score: 125
# Run: 753, exploration: 0.01, score: 301
# Run: 754, exploration: 0.01, score: 334
# Run: 755, exploration: 0.01, score: 343
# Run: 756, exploration: 0.01, score: 219
# Run: 757, exploration: 0.01, score: 20
# Run: 758, exploration: 0.01, score: 347
# Run: 759, exploration: 0.01, score: 500
# Run: 760, exploration: 0.01, score: 122
# Run: 761, exploration: 0.01, score: 121
# Run: 762, exploration: 0.01, score: 500
# Run: 763, exploration: 0.01, score: 296
# Run: 764, exploration: 0.01, score: 216
# Run: 765, exploration: 0.01, score: 386
# Run: 766, exploration: 0.01, score: 177
# Run: 767, exploration: 0.01, score: 500
# Run: 768, exploration: 0.01, score: 154
# Run: 769, exploration: 0.01, score: 290
# Run: 770, exploration: 0.01, score: 246
# Run: 771, exploration: 0.01, score: 429
# Run: 772, exploration: 0.01, score: 152
# Run: 773, exploration: 0.01, score: 229
# Run: 774, exploration: 0.01, score: 115
# Run: 775, exploration: 0.01, score: 147
# Run: 776, exploration: 0.01, score: 500
# Run: 777, exploration: 0.01, score: 131
# Run: 778, exploration: 0.01, score: 206
# Run: 779, exploration: 0.01, score: 443
# Run: 780, exploration: 0.01, score: 500
# Run: 781, exploration: 0.01, score: 500
# Run: 782, exploration: 0.01, score: 171
# Run: 783, exploration: 0.01, score: 147
# Run: 784, exploration: 0.01, score: 147
# Run: 785, exploration: 0.01, score: 500
# Run: 786, exploration: 0.01, score: 500
# Run: 787, exploration: 0.01, score: 492
# Run: 788, exploration: 0.01, score: 325
# Run: 789, exploration: 0.01, score: 241
# Run: 790, exploration: 0.01, score: 354
# Run: 791, exploration: 0.01, score: 276
# Run: 792, exploration: 0.01, score: 172
# Run: 793, exploration: 0.01, score: 292
# Run: 794, exploration: 0.01, score: 195
# Run: 795, exploration: 0.01, score: 112
# Run: 796, exploration: 0.01, score: 222
# Run: 797, exploration: 0.01, score: 468
# Run: 798, exploration: 0.01, score: 264
# Run: 799, exploration: 0.01, score: 349
# Run: 800, exploration: 0.01, score: 234
# Run: 801, exploration: 0.01, score: 30
# Run: 802, exploration: 0.01, score: 85
# Run: 803, exploration: 0.01, score: 282
# Run: 804, exploration: 0.01, score: 201
# Run: 805, exploration: 0.01, score: 461
# Run: 806, exploration: 0.01, score: 266
# Run: 807, exploration: 0.01, score: 203
# Run: 808, exploration: 0.01, score: 16
# Run: 809, exploration: 0.01, score: 10
# Run: 810, exploration: 0.01, score: 10
# Run: 811, exploration: 0.01, score: 10
# Run: 812, exploration: 0.01, score: 193
# Run: 813, exploration: 0.01, score: 207
# Run: 814, exploration: 0.01, score: 120
# Run: 815, exploration: 0.01, score: 500
# Run: 816, exploration: 0.01, score: 107
# Run: 817, exploration: 0.01, score: 346
# Run: 818, exploration: 0.01, score: 153
# Run: 819, exploration: 0.01, score: 318
# Run: 820, exploration: 0.01, score: 192
# Run: 821, exploration: 0.01, score: 425
# Run: 822, exploration: 0.01, score: 134
# Run: 823, exploration: 0.01, score: 417
# Run: 824, exploration: 0.01, score: 167
# Run: 825, exploration: 0.01, score: 219
# Run: 826, exploration: 0.01, score: 141
# Run: 827, exploration: 0.01, score: 111
# Run: 828, exploration: 0.01, score: 467
# Run: 829, exploration: 0.01, score: 158
# Run: 830, exploration: 0.01, score: 310
# Run: 831, exploration: 0.01, score: 96
# Run: 832, exploration: 0.01, score: 404
# Run: 833, exploration: 0.01, score: 100
# Run: 834, exploration: 0.01, score: 342
# Run: 835, exploration: 0.01, score: 262
# Run: 836, exploration: 0.01, score: 138
# Run: 837, exploration: 0.01, score: 109
# Run: 838, exploration: 0.01, score: 208
# Run: 839, exploration: 0.01, score: 173
# Run: 840, exploration: 0.01, score: 157
# Run: 841, exploration: 0.01, score: 312
# Run: 842, exploration: 0.01, score: 226
# Run: 843, exploration: 0.01, score: 321
# Run: 844, exploration: 0.01, score: 199
# Run: 845, exploration: 0.01, score: 295
# Run: 846, exploration: 0.01, score: 126
# Run: 847, exploration: 0.01, score: 119
# Run: 848, exploration: 0.01, score: 179
# Run: 849, exploration: 0.01, score: 223
# Run: 850, exploration: 0.01, score: 335
# Run: 851, exploration: 0.01, score: 80
# Run: 852, exploration: 0.01, score: 106
# Run: 853, exploration: 0.01, score: 108
# Run: 854, exploration: 0.01, score: 105
# Run: 855, exploration: 0.01, score: 117
# Run: 856, exploration: 0.01, score: 143
# Run: 857, exploration: 0.01, score: 265
# Run: 858, exploration: 0.01, score: 137
# Run: 859, exploration: 0.01, score: 131
# Run: 860, exploration: 0.01, score: 239
# Run: 861, exploration: 0.01, score: 198
# Run: 862, exploration: 0.01, score: 130
# Run: 863, exploration: 0.01, score: 117
# Run: 864, exploration: 0.01, score: 122
# Run: 865, exploration: 0.01, score: 157
# Run: 866, exploration: 0.01, score: 360
# Run: 867, exploration: 0.01, score: 326
# Run: 868, exploration: 0.01, score: 147
# Run: 869, exploration: 0.01, score: 100
# Run: 870, exploration: 0.01, score: 141
# Run: 871, exploration: 0.01, score: 62
# Run: 872, exploration: 0.01, score: 277
# Run: 873, exploration: 0.01, score: 107
# Run: 874, exploration: 0.01, score: 208
# Run: 875, exploration: 0.01, score: 354
# Run: 876, exploration: 0.01, score: 116
# Run: 877, exploration: 0.01, score: 73
# Run: 878, exploration: 0.01, score: 249
# Run: 879, exploration: 0.01, score: 485
# Run: 880, exploration: 0.01, score: 500
# Run: 881, exploration: 0.01, score: 219
# Run: 882, exploration: 0.01, score: 171
# Run: 883, exploration: 0.01, score: 475
# Run: 884, exploration: 0.01, score: 226
# Run: 885, exploration: 0.01, score: 261
# Run: 886, exploration: 0.01, score: 166
# Run: 887, exploration: 0.01, score: 246
# Run: 888, exploration: 0.01, score: 222
# Run: 889, exploration: 0.01, score: 496
# Run: 890, exploration: 0.01, score: 95
# Run: 891, exploration: 0.01, score: 147
# Run: 892, exploration: 0.01, score: 258
# Run: 893, exploration: 0.01, score: 316
# Run: 894, exploration: 0.01, score: 24
# Run: 895, exploration: 0.01, score: 127
# Run: 896, exploration: 0.01, score: 353
# Run: 897, exploration: 0.01, score: 181
# Run: 898, exploration: 0.01, score: 495
# Run: 899, exploration: 0.01, score: 178
# Run: 900, exploration: 0.01, score: 151
# Run: 901, exploration: 0.01, score: 158
# Run: 902, exploration: 0.01, score: 325
# Run: 903, exploration: 0.01, score: 215
# Run: 904, exploration: 0.01, score: 19
# Run: 905, exploration: 0.01, score: 43
# Run: 906, exploration: 0.01, score: 366
# Run: 907, exploration: 0.01, score: 112
# Run: 908, exploration: 0.01, score: 129
# Run: 909, exploration: 0.01, score: 117
# Run: 910, exploration: 0.01, score: 134
# Run: 911, exploration: 0.01, score: 121
# Run: 912, exploration: 0.01, score: 118
# Run: 913, exploration: 0.01, score: 195
# Run: 914, exploration: 0.01, score: 389
# Run: 915, exploration: 0.01, score: 41
# Run: 916, exploration: 0.01, score: 46
# Run: 917, exploration: 0.01, score: 63
# Run: 918, exploration: 0.01, score: 95
# Run: 919, exploration: 0.01, score: 28
# Run: 920, exploration: 0.01, score: 17
# Run: 921, exploration: 0.01, score: 143
# Run: 922, exploration: 0.01, score: 103
# Run: 923, exploration: 0.01, score: 64
# Run: 924, exploration: 0.01, score: 24
# Run: 925, exploration: 0.01, score: 186
# Run: 926, exploration: 0.01, score: 255
# Run: 927, exploration: 0.01, score: 20
# Run: 928, exploration: 0.01, score: 28
# Run: 929, exploration: 0.01, score: 17
# Run: 930, exploration: 0.01, score: 172
# Run: 931, exploration: 0.01, score: 262
# Run: 932, exploration: 0.01, score: 37
# Run: 933, exploration: 0.01, score: 18
# Run: 934, exploration: 0.01, score: 32
# Run: 935, exploration: 0.01, score: 71
# Run: 936, exploration: 0.01, score: 134
# Run: 937, exploration: 0.01, score: 62
# Run: 938, exploration: 0.01, score: 23
# Run: 939, exploration: 0.01, score: 19
# Run: 940, exploration: 0.01, score: 111
# Run: 941, exploration: 0.01, score: 103
# Run: 942, exploration: 0.01, score: 173
# Run: 943, exploration: 0.01, score: 52
# Run: 944, exploration: 0.01, score: 347
# Run: 945, exploration: 0.01, score: 212
# Run: 946, exploration: 0.01, score: 335
# Run: 947, exploration: 0.01, score: 32
# Run: 948, exploration: 0.01, score: 33
# Run: 949, exploration: 0.01, score: 330
# Run: 950, exploration: 0.01, score: 315
# Run: 951, exploration: 0.01, score: 500
# Run: 952, exploration: 0.01, score: 276
# Run: 953, exploration: 0.01, score: 262
# Run: 954, exploration: 0.01, score: 232
# Run: 955, exploration: 0.01, score: 98
# Run: 956, exploration: 0.01, score: 261
# Run: 957, exploration: 0.01, score: 134
# Run: 958, exploration: 0.01, score: 114
# Run: 959, exploration: 0.01, score: 150
# Run: 960, exploration: 0.01, score: 131
# Run: 961, exploration: 0.01, score: 307
# Run: 962, exploration: 0.01, score: 271
# Run: 963, exploration: 0.01, score: 89
# Run: 964, exploration: 0.01, score: 77
# Run: 965, exploration: 0.01, score: 115
# Run: 966, exploration: 0.01, score: 100
# Run: 967, exploration: 0.01, score: 214
# Run: 968, exploration: 0.01, score: 268
# Run: 969, exploration: 0.01, score: 190
# Run: 970, exploration: 0.01, score: 321
# Run: 971, exploration: 0.01, score: 398
# Run: 972, exploration: 0.01, score: 325
# Run: 973, exploration: 0.01, score: 115
# Run: 974, exploration: 0.01, score: 126
# Run: 975, exploration: 0.01, score: 438
# Run: 976, exploration: 0.01, score: 257
# Run: 977, exploration: 0.01, score: 102
# Run: 978, exploration: 0.01, score: 237
# Run: 979, exploration: 0.01, score: 118
# Run: 980, exploration: 0.01, score: 59
# Run: 981, exploration: 0.01, score: 131
# Run: 982, exploration: 0.01, score: 239
# Run: 983, exploration: 0.01, score: 315
# Run: 984, exploration: 0.01, score: 260
# Run: 985, exploration: 0.01, score: 418
# Run: 986, exploration: 0.01, score: 134
# Run: 987, exploration: 0.01, score: 230
# Run: 988, exploration: 0.01, score: 117
# Run: 989, exploration: 0.01, score: 500
# Run: 990, exploration: 0.01, score: 113
# Run: 991, exploration: 0.01, score: 352
# Run: 992, exploration: 0.01, score: 74
# Run: 993, exploration: 0.01, score: 271
# Run: 994, exploration: 0.01, score: 136
# Run: 995, exploration: 0.01, score: 370
# Run: 996, exploration: 0.01, score: 302
# Run: 997, exploration: 0.01, score: 159
# Run: 998, exploration: 0.01, score: 142
# Run: 999, exploration: 0.01, score: 272
# Run: 1000, exploration: 0.01, score: 115
